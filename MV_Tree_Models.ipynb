# %% [markdown]
# ## The purpose of this notebook is to classify Nation State Failure events in the next 5 years, better than a baseline guess. Baseline guesses classify whether a state failure event will occur based on whether there were state failure events for a nation in the last 5 years.

# %%
import pandas as pd

# %%
train = pd.read_csv('https://raw.githubusercontent.com/ddodds42/DS_Unit_2_Build_DAVID_DODDS/master/train_github.csv')
val = pd.read_csv('https://raw.githubusercontent.com/ddodds42/DS_Unit_2_Build_DAVID_DODDS/master/val_github.csv')
test = pd.read_csv('https://raw.githubusercontent.com/ddodds42/DS_Unit_2_Build_DAVID_DODDS/master/test_github.csv')

# %% [markdown]
# ## Columns named with a T_ are targets. C_ indicates a feature measuring state centralization, E_ indicates a feature measuring economic inclusion, and P_ indicates a feature measuring political inclusion.

# %%
train.columns
# Out:
# Index(['NS_code_from_gini', 'Nation_State', 'T_HDI_Mean_plus_5',
#        'T_HDI_Trend_plus_5', 'T_State_Fail_yr_1', 'T_State_Fail_plus_5',
#        'T_State_Fail_yr_5', 'year0', 'CWGI_Poli_Stabl_Mean_minus_4',
#        'CWGI_Poli_Stabl_Trend_minus_4', 'CWGI_RoL_Mean_minus_4',
#        'CWGI_RoL_Trend_minus_4', 'E_GINI_Mean_minus_4', 'E_GINI_Trend_minus_4',
#        'PCPI_std_Mean_minus_4', 'PCPI_std_Trend_minus_4',
#        'PWGI_Corrupt_Ctrl_Mean_minus_4', 'PWGI_Corrupt_Ctrl_Trend_minus_4',
#        'PWGI_Voice_Acct_Mean_minus_4', 'PWGI_Voice_Acct_Trend_minus_4'],
#       dtype='object')

# %%
features = ['NS_code_from_gini', 'year0', 'CWGI_Poli_Stabl_Mean_minus_4',
       'CWGI_Poli_Stabl_Trend_minus_4', 'CWGI_RoL_Mean_minus_4',
       'CWGI_RoL_Trend_minus_4', 'E_GINI_Mean_minus_4', 'E_GINI_Trend_minus_4',
       'PCPI_std_Mean_minus_4', 'PCPI_std_Trend_minus_4',
       'PWGI_Corrupt_Ctrl_Mean_minus_4', 'PWGI_Corrupt_Ctrl_Trend_minus_4',
       'PWGI_Voice_Acct_Mean_minus_4', 'PWGI_Voice_Acct_Trend_minus_4']
target = 'T_State_Fail_yr_5'

# %%
X_train = train[features]
X_val = val[features]
X_test = test[features]

y_train = train[target]
y_val = val[target]
y_test = test[target]

# %%
import category_encoders as ce
from sklearn.pipeline import make_pipeline
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# %%
pipeline = make_pipeline(
    ce.OrdinalEncoder(), 
    DecisionTreeClassifier(max_depth=13, random_state=42)
)

pipeline.fit(X_train, y_train)
y_predt = pipeline.predict(X_train)
y_predv = pipeline.predict(X_val)
print('Yr 5 Train F_Score', f1_score(y_train, y_predt))
print('Yr 5 Validation F_Score', f1_score(y_val, y_predv))
print('Yr 5 Validation roc_auc_score', roc_auc_score(y_val, y_predv))
# Out:
# Yr 5 Train F_Score 0.9469598965071151
# Yr 5 Validation F_Score 0.6617647058823529
# Yr 5 Validation roc_auc_score 0.816712615267611

# %% [markdown]
# ## ^^ T_State_Fail_yr_5: MVP model beat Initial baseline by 17 points. It is 17 points better at predicting a state failure event 5 years from the present. ^^

# %%
target0 = 'T_State_Fail_plus_5'

y_train0 = train[target0]
y_val0 = val[target0]
y_test0 = test[target0]

# %%
pipeline0 = make_pipeline(
    ce.OrdinalEncoder(), 
    DecisionTreeClassifier(max_depth=13, random_state=42)
)

pipeline0.fit(X_train, y_train0)
y_predt = pipeline0.predict(X_train)
y_predv = pipeline0.predict(X_val)
print('Nx 5 Train F_Score', f1_score(y_train0, y_predt))
print('Nx 5 Validation F_Score', f1_score(y_val0, y_predv))
# Out:
# Nx 5 Train F_Score 0.9623493975903615
# Nx 5 Validation F_Score 0.7481481481481481

# %% [markdown]
# ## T_State_Fail_plus_5: MVP model beat Initial baseline by almost 8 points. It is almost 8 points better at predicting a state failure event in any of the next 5 years. ^^

# %%
target1 = 'T_State_Fail_yr_1'

y_train1 = train[target1]
y_val1 = val[target1]
y_test1 = test[target1]

# %%
pipeline1 = make_pipeline(
    ce.OrdinalEncoder(), 
    DecisionTreeClassifier(max_depth=17, random_state=42)
)

pipeline1.fit(X_train, y_train1)
y_predt = pipeline1.predict(X_train)
y_predv = pipeline1.predict(X_val)
print('Yr 1 Train F_Score', f1_score(y_train1, y_predt))
print('Yr 1 Validation F_Score', f1_score(y_val1, y_predv))
# Out:
# Yr 1 Train F_Score 0.9988109393579072
# Yr 1 Validation F_Score 0.6413043478260869

# %% [markdown]
# ## ^^ Decision Tree Classifier failed to beat baseline for T_State_Fail_yr_1. To beat baseline for predicting a state failure event next year, a model must have an F1 Score of 0.80457 or greater. ^^

# %%
from sklearn.linear_model import LogisticRegression

# %%
features1 = ['year0', 'CWGI_Poli_Stabl_Mean_minus_4',
       'CWGI_Poli_Stabl_Trend_minus_4', 'CWGI_RoL_Mean_minus_4',
       'CWGI_RoL_Trend_minus_4', 'E_GINI_Mean_minus_4', 'E_GINI_Trend_minus_4',
       'PCPI_std_Mean_minus_4', 'PCPI_std_Trend_minus_4',
       'PWGI_Corrupt_Ctrl_Mean_minus_4', 'PWGI_Corrupt_Ctrl_Trend_minus_4',
       'PWGI_Voice_Acct_Mean_minus_4', 'PWGI_Voice_Acct_Trend_minus_4']

# %%
X_train1 = train[features1]
X_val1 = val[features1]
X_test1 = test[features1]

# %%
model = LogisticRegression(max_iter=2000)
model.fit(X_train1, y_train1)
y_predt = model.predict(X_train1)
y_predv = model.predict(X_val1)
print('Yr 1 Train F_Score', f1_score(y_train1, y_predt))
print('Yr 1 Validation F_Score', f1_score(y_val1, y_predv))
# Out:
# Yr 1 Train F_Score 0.48233486943164366
# Yr 1 Validation F_Score 0.4084507042253521

# %% [markdown]
# ## ^^ For predicting state failure events next year, Logistic Regression has half the F1_score of baseline. ^^

# %%
from sklearn.linear_model import LogisticRegressionCV

# %%
explore = pd.read_csv('https://raw.githubusercontent.com/ddodds42/DS_Unit_2_Build_DAVID_DODDS/master/explore_github.csv')

# %%
X_explore = explore[features1]
y_explore = explore[target1]

# %%
model0 = LogisticRegressionCV(scoring='f1', max_iter=2000)
model0.fit(X_explore, y_explore)
print('Yr 1 Validation F_Score', model0.score(X_explore, y_explore))
# Out:
# Yr 1 Validation F_Score 0.46134020618556704

# %% [markdown]
# ## ^^ Cross Validated Logistic Regression is not much better. ^^

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipeline2 = make_pipeline(
    ce.OrdinalEncoder(), 
    RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=42)
)

pipeline2.fit(X_train, y_train1)
y_predt = pipeline2.predict(X_train)
y_predv = pipeline2.predict(X_val)
print('Yr 1 Train F_Score', f1_score(y_train1, y_predt))
print('Yr 1 Validation F_Score', f1_score(y_val1, y_predv))
# Out:
# Yr 1 Train F_Score 1.0
# Yr 1 Validation F_Score 0.675

# %% [markdown]
# ## ^^ Random Forest Classifier has the best F1_score yet, ~0.67, but is still ~13 points worse than baseline. ^^

# %%
from xgboost import XGBClassifier

# %%
# from sklearn.metrics import make_scorer
import numpy as np
def f1eval(y_pred, dtrain):
    y_true = dtrain.get_label()
    err = 1-(f1_score(y_true, np.round(y_pred)))
    return 'f1_err', err

encoder = ce.OrdinalEncoder()
X_train_enc = encoder.fit_transform(X_train)
X_val_enc = encoder.transform(X_val)

model1 = XGBClassifier(
    n_estimators = 1000,
    max_depth = 8,
    learning_rate = 0.25,
    n_jobs = -1,
    disable_default_eval_metric = 1
)

evaluators = [(X_train_enc, y_train),
             (X_val_enc, y_val)]

model1.fit(X_train_enc, y_train,
         eval_set = evaluators,
         eval_metric = f1eval,
         early_stopping_rounds = 50)
# Out:
# [0]	validation_0-f1_err:0.435169	validation_1-f1_err:0.592233
# Multiple eval metrics have been passed: 'validation_1-f1_err' will be used for early stopping.
#
# Will train until validation_1-f1_err hasn't improved in 50 rounds.
# [1]	validation_0-f1_err:0.275272	validation_1-f1_err:0.495935
# [2]	validation_0-f1_err:0.261006	validation_1-f1_err:0.5
# [3]	validation_0-f1_err:0.238095	validation_1-f1_err:0.5
# [4]	validation_0-f1_err:0.1994	validation_1-f1_err:0.438017
# [5]	validation_0-f1_err:0.181149	validation_1-f1_err:0.376
# [6]	validation_0-f1_err:0.148629	validation_1-f1_err:0.398374
# [7]	validation_0-f1_err:0.127119	validation_1-f1_err:0.333333
# [8]	validation_0-f1_err:0.11831	validation_1-f1_err:0.306452
# [9]	validation_0-f1_err:0.106145	validation_1-f1_err:0.307087
# [10]	validation_0-f1_err:0.095436	validation_1-f1_err:0.286822
# [11]	validation_0-f1_err:0.084699	validation_1-f1_err:0.282443
# [12]	validation_0-f1_err:0.079235	validation_1-f1_err:0.28125
# [13]	validation_0-f1_err:0.079019	validation_1-f1_err:0.286822
# [14]	validation_0-f1_err:0.070461	validation_1-f1_err:0.291339
# [15]	validation_0-f1_err:0.064865	validation_1-f1_err:0.28125
# [16]	validation_0-f1_err:0.064865	validation_1-f1_err:0.275591
# [17]	validation_0-f1_err:0.060565	validation_1-f1_err:0.265625
# [18]	validation_0-f1_err:0.05914	validation_1-f1_err:0.265625
# [19]	validation_0-f1_err:0.046481	validation_1-f1_err:0.282443
# [20]	validation_0-f1_err:0.043709	validation_1-f1_err:0.282443
# [21]	validation_0-f1_err:0.04106	validation_1-f1_err:0.292308
# [22]	validation_0-f1_err:0.038309	validation_1-f1_err:0.278195
# [23]	validation_0-f1_err:0.031496	validation_1-f1_err:0.259259
# [24]	validation_0-f1_err:0.031496	validation_1-f1_err:0.264706
# [25]	validation_0-f1_err:0.027451	validation_1-f1_err:0.259259
# [26]	validation_0-f1_err:0.023438	validation_1-f1_err:0.264706
# [27]	validation_0-f1_err:0.023438	validation_1-f1_err:0.275362
# [28]	validation_0-f1_err:0.023438	validation_1-f1_err:0.280576
# [29]	validation_0-f1_err:0.022107	validation_1-f1_err:0.279412
# [30]	validation_0-f1_err:0.019557	validation_1-f1_err:0.293233
# [31]	validation_0-f1_err:0.015584	validation_1-f1_err:0.303704
# [32]	validation_0-f1_err:0.015584	validation_1-f1_err:0.294118
# [33]	validation_0-f1_err:0.011643	validation_1-f1_err:0.294118
# [34]	validation_0-f1_err:0.010336	validation_1-f1_err:0.294118
# [35]	validation_0-f1_err:0.009032	validation_1-f1_err:0.304348
# [36]	validation_0-f1_err:0.006452	validation_1-f1_err:0.29927
# [37]	validation_0-f1_err:0.005155	validation_1-f1_err:0.294118
# [38]	validation_0-f1_err:0.002571	validation_1-f1_err:0.294118
# [39]	validation_0-f1_err:0.003861	validation_1-f1_err:0.29927
# [40]	validation_0-f1_err:0.003861	validation_1-f1_err:0.29927
# [41]	validation_0-f1_err:0.003861	validation_1-f1_err:0.294118
# [42]	validation_0-f1_err:0.002571	validation_1-f1_err:0.303704
# [43]	validation_0-f1_err:0.002571	validation_1-f1_err:0.313869
# [44]	validation_0-f1_err:0.002571	validation_1-f1_err:0.298507
# [45]	validation_0-f1_err:0	validation_1-f1_err:0.298507
# [46]	validation_0-f1_err:0	validation_1-f1_err:0.298507
# [47]	validation_0-f1_err:0	validation_1-f1_err:0.29771
# [48]	validation_0-f1_err:0	validation_1-f1_err:0.287879
# [49]	validation_0-f1_err:0	validation_1-f1_err:0.287879
# [50]	validation_0-f1_err:0	validation_1-f1_err:0.287879
# [51]	validation_0-f1_err:0	validation_1-f1_err:0.293233
# [52]	validation_0-f1_err:0	validation_1-f1_err:0.30303
# [53]	validation_0-f1_err:0	validation_1-f1_err:0.298507
# [54]	validation_0-f1_err:0	validation_1-f1_err:0.298507
# [55]	validation_0-f1_err:0	validation_1-f1_err:0.293233
# [56]	validation_0-f1_err:0	validation_1-f1_err:0.30303
# [57]	validation_0-f1_err:0	validation_1-f1_err:0.318182
# [58]	validation_0-f1_err:0	validation_1-f1_err:0.308271
# [59]	validation_0-f1_err:0	validation_1-f1_err:0.328244
# [60]	validation_0-f1_err:0	validation_1-f1_err:0.318182
# [61]	validation_0-f1_err:0	validation_1-f1_err:0.318182
# [62]	validation_0-f1_err:0	validation_1-f1_err:0.318182
# [63]	validation_0-f1_err:0	validation_1-f1_err:0.323077
# [64]	validation_0-f1_err:0	validation_1-f1_err:0.323077
# [65]	validation_0-f1_err:0	validation_1-f1_err:0.323077
# [66]	validation_0-f1_err:0	validation_1-f1_err:0.312977
# [67]	validation_0-f1_err:0	validation_1-f1_err:0.307692
# [68]	validation_0-f1_err:0	validation_1-f1_err:0.293233
# [69]	validation_0-f1_err:0	validation_1-f1_err:0.287879
# [70]	validation_0-f1_err:0	validation_1-f1_err:0.293233
# [71]	validation_0-f1_err:0	validation_1-f1_err:0.29771
# [72]	validation_0-f1_err:0	validation_1-f1_err:0.307692
# [73]	validation_0-f1_err:0	validation_1-f1_err:0.292308
# Stopping. Best iteration:
# [23]	validation_0-f1_err:0.031496	validation_1-f1_err:0.259259
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1,
#               disable_default_eval_metric=1, gamma=0, learning_rate=0.25,
#               max_delta_step=0, max_depth=8, min_child_weight=1, missing=None,
#               n_estimators=1000, n_jobs=-1, nthread=None,
#               objective='binary:logistic', random_state=0, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#               subsample=1, verbosity=1)

# %% [markdown]
# ## XG Boost Classsifier is still closer, but is still worse than baseline by about 6 points for predicting state failure events next year (0.80457 is baseline F1). ^^

# %%
import eli5
from eli5.sklearn import PermutationImportance

# %%
transformer = ce.OrdinalEncoder()

X_train_trans = transformer.fit_transform(X_train)
X_val_trans = transformer.transform(X_val)

model2 = DecisionTreeClassifier(max_depth=13, random_state=42)
model2.fit(X_train_trans, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=13, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
permuter = PermutationImportance(
    model2,
    scoring='f1',
    n_iter=5,
    random_state=42
)

permuter.fit(X_val_trans, y_val)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                        class_weight=None,
#                                                        criterion='gini',
#                                                        max_depth=13,
#                                                        max_features=None,
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        presort='deprecated',
#                                                        random_state=42,
#                                                        splitter='best'),
#                       n_iter=5, random_state=42, refit=True, scoring='f1')

# %%
feature_list = X_val_trans.columns.tolist()

# %%
eli5.show_weights(
    permuter,
    top=None,
    feature_names=feature_list
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3078
#
#                     &plusmn; 0.0483
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_Poli_Stabl_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.67%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2931
#
#                     &plusmn; 0.0167
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Corrupt_Ctrl_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.84%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1878
#
#                     &plusmn; 0.0507
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_RoL_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1650
#
#                     &plusmn; 0.0514
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Voice_Acct_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1319
#
#                     &plusmn; 0.0164
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 E_GINI_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.94%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0993
#
#                     &plusmn; 0.0437
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 year0
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0934
#
#                     &plusmn; 0.0175
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PCPI_std_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.82%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0712
#
#                     &plusmn; 0.0432
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Corrupt_Ctrl_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0571
#
#                     &plusmn; 0.0219
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NS_code_from_gini
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.87%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0441
#
#                     &plusmn; 0.0218
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PCPI_std_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.82%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0329
#
#                     &plusmn; 0.0297
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 E_GINI_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0325
#
#                     &plusmn; 0.0307
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_RoL_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.17%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0188
#
#                     &plusmn; 0.0158
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_Poli_Stabl_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.24%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0182
#
#                     &plusmn; 0.0141
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Voice_Acct_Trend_minus_4
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# ## ^^ Feature importances for predicting state failure events 5 years from the present. 5-year means are much more important than 5-year trend features. ^^

# %%
model3 = DecisionTreeClassifier(max_depth=13, random_state=42)
model3.fit(X_train_trans, y_train0)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=13, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
permuter0 = PermutationImportance(
    model3,
    scoring='f1',
    n_iter=5,
    random_state=42
)

permuter0.fit(X_val_trans, y_val0)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=DecisionTreeClassifier(ccp_alpha=0.0,
#                                                        class_weight=None,
#                                                        criterion='gini',
#                                                        max_depth=13,
#                                                        max_features=None,
#                                                        max_leaf_nodes=None,
#                                                        min_impurity_decrease=0.0,
#                                                        min_impurity_split=None,
#                                                        min_samples_leaf=1,
#                                                        min_samples_split=2,
#                                                        min_weight_fraction_leaf=0.0,
#                                                        presort='deprecated',
#                                                        random_state=42,
#                                                        splitter='best'),
#                       n_iter=5, random_state=42, refit=True, scoring='f1')

# %%
eli5.show_weights(
    permuter0,
    top=None,
    feature_names=feature_list
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.3754
#
#                     &plusmn; 0.0515
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_Poli_Stabl_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.72%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2319
#
#                     &plusmn; 0.0280
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Corrupt_Ctrl_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1857
#
#                     &plusmn; 0.0449
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_RoL_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 92.23%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0973
#
#                     &plusmn; 0.0106
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PCPI_std_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 93.51%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0752
#
#                     &plusmn; 0.0205
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Voice_Acct_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.03%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0668
#
#                     &plusmn; 0.0168
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NS_code_from_gini
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 94.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0603
#
#                     &plusmn; 0.0155
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_Poli_Stabl_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.15%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0495
#
#                     &plusmn; 0.0275
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 E_GINI_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 97.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0196
#
#                     &plusmn; 0.0080
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 year0
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.02%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0138
#
#                     &plusmn; 0.0242
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Corrupt_Ctrl_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0086
#
#                     &plusmn; 0.0205
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Voice_Acct_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.65%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0079
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PCPI_std_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.13%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0042
#
#                     &plusmn; 0.0063
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_RoL_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(0, 100.00%, 99.66%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 -0.0011
#
#                     &plusmn; 0.0206
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 E_GINI_Trend_minus_4
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# ## ^^ Feature importances for predicting state failure events in any of the next 5 years. Again, 5-year means are more important than 5-year trend features. ^^

# %%
permuter1 = PermutationImportance(
    model1,
    scoring='f1',
    n_iter=5,
    random_state=42
)

permuter1.fit(X_val_trans, y_val1)
# Out:
# PermutationImportance(cv='prefit',
#                       estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                               colsample_bylevel=1,
#                                               colsample_bynode=1,
#                                               colsample_bytree=1,
#                                               disable_default_eval_metric=1,
#                                               gamma=0, learning_rate=0.25,
#                                               max_delta_step=0, max_depth=8,
#                                               min_child_weight=1, missing=None,
#                                               n_estimators=1000, n_jobs=-1,
#                                               nthread=None,
#                                               objective='binary:logistic',
#                                               random_state=0, reg_alpha=0,
#                                               reg_lambda=1, scale_pos_weight=1,
#                                               seed=None, silent=None,
#                                               subsample=1, verbosity=1),
#                       n_iter=5, random_state=42, refit=True, scoring='f1')

# %%
eli5.show_weights(
    permuter1,
    top=None,
    feature_names=feature_list
)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2972
#
#                     &plusmn; 0.0628
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_Poli_Stabl_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.85%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.2190
#
#                     &plusmn; 0.0427
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Corrupt_Ctrl_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.91%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1118
#
#                     &plusmn; 0.0323
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Voice_Acct_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.18%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1076
#
#                     &plusmn; 0.0410
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 NS_code_from_gini
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0961
#
#                     &plusmn; 0.0423
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_RoL_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.93%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0305
#
#                     &plusmn; 0.0294
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PCPI_std_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 95.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0304
#
#                     &plusmn; 0.0207
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PCPI_std_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.05%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0292
#
#                     &plusmn; 0.0406
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 E_GINI_Mean_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.58%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0239
#
#                     &plusmn; 0.0121
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Corrupt_Ctrl_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.64%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0232
#
#                     &plusmn; 0.0063
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_RoL_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.78%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0219
#
#                     &plusmn; 0.0072
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 CWGI_Poli_Stabl_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 96.92%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0205
#
#                     &plusmn; 0.0397
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 PWGI_Voice_Acct_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 98.55%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0070
#
#                     &plusmn; 0.0121
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 E_GINI_Trend_minus_4
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 99.54%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0014
#
#                     &plusmn; 0.0281
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 year0
#             </td>
#         </tr>
#
#
#     </tbody>
# </table>

# %% [markdown]
# ## ^^ Feature importances for predicting state failure events next year. ^^
